# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# ================================
# 그래프 설정
# ================================
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 한글 폰트
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지
plt.style.use('fivethirtyeight')  # 그래프 스타일 설정
plt.rcParams["figure.figsize"] = 10, 6 # 기본 그래프 크기 설정

def cosine_similarity_manual(A, B):
    # 내적 계산 (dot product)
    dot_product = np.sum(A * B)
    
    # A의 크기(norm) 계산
    norm_A = np.sqrt(np.sum(A**2))
    
    # B의 크기(norm) 계산
    norm_B = np.sqrt(np.sum(B**2))
    
    # 코사인 유사도 계산
    similarity = dot_product / (norm_A * norm_B)
    
    return similarity

# 두 벡터 정의
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

# 코사인 유사도 계산
similarity = cosine_similarity_manual(A, B)
print(similarity)  # 결과 출력

# 두 벡터 A와 B를 NumPy 배열로 정의
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

# 유클리드 거리를 계산하는 함수
def euclidean_distance(vec_a, vec_b):
    """
    NumPy를 사용하여 두 벡터 사이의 유클리드 거리를 계산합니다.
    """
    # 1. 두 벡터의 차이를 구합니다 (B - A)
    difference = vec_b - vec_a

    # 2. 각 차이값을 제곱합니다
    squared_difference = difference**2

    # 3. 제곱된 차이값들을 모두 더합니다
    sum_squared = np.sum(squared_difference)

    # 4. 최종적으로 합산된 값의 제곱근을 구합니다 (L2 Norm)
    distance = np.sqrt(sum_squared)

    # 또는 NumPy의 내장 함수를 사용한 더 간결한 방법:
    # distance = np.linalg.norm(vec_a - vec_b)

    return distance

# 거리 계산 및 결과 출력
distance = euclidean_distance(A, B)
print(f"벡터 A: {A}")
print(f"벡터 B: {B}")
print(f"유클리드 거리: {distance}")


# 동전 던지기 시뮬레이션
trials = np.random.choice(["앞", "뒤"], size=10000, p=[0.5, 0.5])
# print(trials)

# 방법 1: Counter 사용
counts = Counter(trials)
print("앞:", counts["앞"], "개")
print("뒤:", counts["뒤"], "개")

# 방법 2: numpy를 이용한 방법
print("앞 개수:", np.count_nonzero(trials == "앞"))
print("뒤 개수:", np.count_nonzero(trials == "뒤"))


# 데이터
x = [1, 2, 3, 4, 5, 6]
label = [3, 6, 7, 12, 15, 18]

# 초기값
W = 0                # 임의의 초기 가중치
lr = 0.01              # 학습률
epochs = 100           # 반복 횟수

# 학습 기록 저장
W_list = []
loss_list = []

# 손실 함수
def compute_loss(W, x, label):
    total = 0
    n = len(x)
    for i in range(n):
        total += (label[i] - W * x[i]) ** 2
    return total / n

# 기울기 계산 함수
def compute_gradient(W, x, label):
    total = 0
    n = len(x)
    for i in range(n):
        total += -2 * x[i] * (label[i] - W * x[i])
    return total / n

# 경사 하강법 반복
for epoch in range(epochs):
    grad = compute_gradient(W, x, label)
    new_W = W - lr * grad

    # 기록
    W_list.append(W)
    loss_list.append(compute_loss(W, x, label))

    # 출력 (감소/증가 여부 표시)
    direction = "⬇ 감소" if grad > 0 else "⬆ 증가"
    print(f"{epoch+1:3d} | W = {W:.4f} | 손실 = {loss_list[-1]:.4f} | dL/dW = {grad:.4f} | {direction}")

    # 업데이트
    W = new_W

# 최종 W 출력
print("\n최적의 W:", round(W, 4))

# 그래프 시각화
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.plot(W_list, loss_list, marker='o')
plt.title("W 변화에 따른 손실(Loss)")
plt.xlabel("W")
plt.ylabel("Loss")

plt.subplot(1,2,2)
plt.plot(W_list, marker='o', color='purple')
plt.title("W 업데이트 과정")
plt.xlabel("Epoch")
plt.ylabel("W 값")

plt.tight_layout()
plt.show()
# Out:
# 0.9746318461970762
# 벡터 A: [1 2 3]
# 벡터 B: [4 5 6]
# 유클리드 거리: 5.196152422706632
# 앞: 4984 개
# 뒤: 5016 개
# 앞 개수: 4984
# 뒤 개수: 5016
#   1 | W = 0.0000 | 손실 = 131.1667 | dL/dW = -89.0000 | ⬆ 증가
#   2 | W = 0.8900 | 손실 = 63.9702 | dL/dW = -62.0033 | ⬆ 증가
#   3 | W = 1.5100 | 손실 = 31.3567 | dL/dW = -43.1957 | ⬆ 증가
#   4 | W = 1.9420 | 손실 = 15.5280 | dL/dW = -30.0930 | ⬆ 증가
#   5 | W = 2.2429 | 손실 = 7.8456 | dL/dW = -20.9648 | ⬆ 증가
#   6 | W = 2.4526 | 손실 = 4.1170 | dL/dW = -14.6055 | ⬆ 증가
#   7 | W = 2.5986 | 손실 = 2.3073 | dL/dW = -10.1751 | ⬆ 증가
#   8 | W = 2.7004 | 손실 = 1.4290 | dL/dW = -7.0887 | ⬆ 증가
#   9 | W = 2.7713 | 손실 = 1.0027 | dL/dW = -4.9384 | ⬆ 증가
#  10 | W = 2.8206 | 손실 = 0.7958 | dL/dW = -3.4405 | ⬆ 증가
#  11 | W = 2.8550 | 손실 = 0.6954 | dL/dW = -2.3968 | ⬆ 증가
#  12 | W = 2.8790 | 손실 = 0.6467 | dL/dW = -1.6698 | ⬆ 증가
#  13 | W = 2.8957 | 손실 = 0.6230 | dL/dW = -1.1633 | ⬆ 증가
#  14 | W = 2.9073 | 손실 = 0.6116 | dL/dW = -0.8104 | ⬆ 증가
#  15 | W = 2.9155 | 손실 = 0.6060 | dL/dW = -0.5646 | ⬆ 증가
#  16 | W = 2.9211 | 손실 = 0.6033 | dL/dW = -0.3933 | ⬆ 증가
#  17 | W = 2.9250 | 손실 = 0.6020 | dL/dW = -0.2740 | ⬆ 증가
#  18 | W = 2.9278 | 손실 = 0.6013 | dL/dW = -0.1909 | ⬆ 증가
#  19 | W = 2.9297 | 손실 = 0.6010 | dL/dW = -0.1330 | ⬆ 증가
#  20 | W = 2.9310 | 손실 = 0.6009 | dL/dW = -0.0927 | ⬆ 증가
#  21 | W = 2.9319 | 손실 = 0.6008 | dL/dW = -0.0645 | ⬆ 증가
#  22 | W = 2.9326 | 손실 = 0.6008 | dL/dW = -0.0450 | ⬆ 증가
#  23 | W = 2.9330 | 손실 = 0.6007 | dL/dW = -0.0313 | ⬆ 증가
#  24 | W = 2.9333 | 손실 = 0.6007 | dL/dW = -0.0218 | ⬆ 증가
#  25 | W = 2.9336 | 손실 = 0.6007 | dL/dW = -0.0152 | ⬆ 증가
#  26 | W = 2.9337 | 손실 = 0.6007 | dL/dW = -0.0106 | ⬆ 증가
#  27 | W = 2.9338 | 손실 = 0.6007 | dL/dW = -0.0074 | ⬆ 증가
#  28 | W = 2.9339 | 손실 = 0.6007 | dL/dW = -0.0051 | ⬆ 증가
#  29 | W = 2.9339 | 손실 = 0.6007 | dL/dW = -0.0036 | ⬆ 증가
#  30 | W = 2.9340 | 손실 = 0.6007 | dL/dW = -0.0025 | ⬆ 증가
#  31 | W = 2.9340 | 손실 = 0.6007 | dL/dW = -0.0017 | ⬆ 증가
#  32 | W = 2.9340 | 손실 = 0.6007 | dL/dW = -0.0012 | ⬆ 증가
#  33 | W = 2.9340 | 손실 = 0.6007 | dL/dW = -0.0008 | ⬆ 증가
#  34 | W = 2.9340 | 손실 = 0.6007 | dL/dW = -0.0006 | ⬆ 증가
#  35 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0004 | ⬆ 증가
#  36 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0003 | ⬆ 증가
#  37 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0002 | ⬆ 증가
#  38 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0001 | ⬆ 증가
#  39 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0001 | ⬆ 증가
#  40 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0001 | ⬆ 증가
#  41 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  42 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  43 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  44 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  45 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  46 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  47 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  48 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  49 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  50 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  51 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  52 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  53 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  54 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  55 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  56 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  57 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  58 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  59 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  60 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  61 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  62 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  63 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  64 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  65 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  66 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  67 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  68 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  69 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  70 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  71 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  72 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  73 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  74 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  75 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  76 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  77 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  78 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  79 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  80 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  81 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  82 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  83 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  84 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  85 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  86 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  87 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  88 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  89 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  90 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  91 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  92 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  93 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  94 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  95 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  96 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  97 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  98 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#  99 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
# 100 | W = 2.9341 | 손실 = 0.6007 | dL/dW = -0.0000 | ⬆ 증가
#
# 최적의 W: 2.9341

# %%
def org_fn(x, y):
    """원본 함수: f(x, y) = x^2*y + 3y"""
    return x**2 * y + 3 * y

# 아주 작은 변화량 (h) 정의
h = 1e-6 # 0.000001

def partial_derivative_x(x, y):
    """
    x에 대한 편미분을 수치적으로 계산 (y는 고정)
    """
    # 정의: lim (h -> 0) [f(x + h, y) - f(x, y)] / h
    return (org_fn(x + h, y) - org_fn(x, y)) / h

def partial_derivative_y(x, y):
    """
    y에 대한 편미분을 수치적으로 계산 (x는 고정)
    """
    # 정의: lim (h -> 0) [f(x, y + h) - f(x, y)] / h
    return (org_fn(x, y + h) - org_fn(x, y)) / h


# 예시 지점 설정
x_val = 2
y_val = 5

# x에 대한 편미분 계산
df_dx_at_point = partial_derivative_x(x_val, y_val)

# y에 대한 편미분 계산
df_dy_at_point = partial_derivative_y(x_val, y_val)

print(f"지점 (x={x_val}, y={y_val}) 에서의 편미분:")
print(f"  ∂f/∂x (근사값): {df_dx_at_point:.6f}")
print(f"  ∂f/∂y (근사값): {df_dy_at_point:.6f}")
# Out:
# 지점 (x=2, y=5) 에서의 편미분:
#   ∂f/∂x (근사값): 20.000005
#   ∂f/∂y (근사값): 7.000000

# %%
import sympy as sp
def partial_derivatives():
    # 변수 선언
    x, y = sp.symbols('x y')
    
    # 함수 정의
    f = x**2 * y + 3 * y

    # 편미분 계산
    df_dx = sp.diff(f, x)  # ∂f/∂x
    df_dy = sp.diff(f, y)  # ∂f/∂y

    # 결과 출력
    print("함수 f(x, y) =", f)
    print("∂f/∂x =", df_dx)
    print("∂f/∂y =", df_dy)

    # 결과 반환
    return df_dx, df_dy

# 실행 예시
partial_derivatives()
# Out:
# 함수 f(x, y) = x**2*y + 3*y
# ∂f/∂x = 2*x*y
# ∂f/∂y = x**2 + 3
# (2*x*y, x**2 + 3)
